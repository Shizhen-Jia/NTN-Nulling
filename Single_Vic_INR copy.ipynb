# %%
import numpy as np
import matplotlib.pyplot as plt
EkT = -174    # Noise energy in dBm/Hz, antenna temperature for vsat: 290K
B = 100e6
Tx_power_dbm = 30 # dbm
Tx_power = 10 ** ((Tx_power_dbm - 30) / 10)

NF = 7  # Noise figure in dB
NF_vsat = 2
NF_bs = 3
# reference signal duration
symbol_time = 18e-6 
preamble_time = symbol_time*4
E_r = Tx_power*preamble_time
E_t = Tx_power*symbol_time


N0_vsat =  10 ** ((EkT + 10 * np.log10(B) + NF_vsat - 30) / 10)
N0_bs =  10 ** ((EkT + 10 * np.log10(B) + NF_bs - 30) / 10)
# For channel estimation interference distribution, h_hat = h + CN~(0, N0/(Tx_power*time))
N0_sigma =  10 ** ((EkT+NF_bs - 30) / 10) /Tx_power/preamble_time



print(N0_vsat)
dsep = 0.5  # Antenna separation in wavelengths

theta0 = 0  # Angle to RX0
theta1 = 15
theta0_rad = theta0 * np.pi / 180
theta1_rad = theta1 * np.pi / 180


ntx_num = np.array([16,32,48,64])
ntx_len = len(ntx_num)
simu_num = 1000 # tota; runing times
gamma_num = 1000
gamma_h1 = np.logspace(-8, -3, gamma_num) # adjustment to h1



inr = np.zeros((ntx_len,simu_num,gamma_num  ))
inr_def = np.zeros((ntx_len,simu_num,gamma_num  ))
G_i = np.zeros((ntx_len,simu_num,gamma_num  ))
gamma_i_r = np.zeros((ntx_len,simu_num,gamma_num  ))
gamma_i_r2 = np.zeros((ntx_len,simu_num,gamma_num  ))
# Out:
# 6.309573444801942e-13

# %%
def beamforming_vec(h0, h1):

    C0 = np.linalg.norm(h0)**2
    C1 = np.linalg.norm(h1)**2
    # rho = np.conj(h0.T) @ h1 / np.sqrt(C1 * C0)
    rho = np.conj(h1.T) @ h0 / np.sqrt(C1 * C0)
    alpha0 = 1 / (np.sqrt(1 - np.abs(rho)**2) * np.sqrt(C0))
    alpha1 = -rho / (np.sqrt(1 - np.abs(rho)**2) * np.sqrt(C1))
    w = alpha0 * h0 + alpha1 * h1

    return w, rho



for ntxn, ntx in enumerate(ntx_num):

    phase0 = 2 * np.pi * np.arange(ntx) * dsep * np.cos(theta0_rad)
    phase1 = 2 * np.pi * np.arange(ntx) * dsep * np.cos(theta1_rad)
    h0 = np.exp(1j * phase0).reshape(-1,1)/np.sqrt(ntx)
    h1 = np.exp(1j * phase1).reshape(-1,1)/np.sqrt(ntx)
    for g, gamma in enumerate(gamma_h1):

 
        for n in range (simu_num):

            G_i[ntxn,n,g] = np.linalg.norm(gamma*h1)**2  /ntx
            gamma_i_r[ntxn,n,g] =  Tx_power*preamble_time*G_i[ntxn,n,g]/N0_bs
            gamma_i_r2[ntxn,n,g] =  G_i[ntxn,n,g]/N0_sigma

            noise = np.sqrt(N0_sigma/2)  * (np.random.randn(*h1.shape) + 1j * np.random.randn(*h1.shape))
            h1_hat = gamma*h1 + noise 
            [w_t,rho_hat] = beamforming_vec(h0, h1_hat)
            [w_real,rho] = beamforming_vec(h0, h1)  # real rho
            
            inr[ntxn,n,g] = (np.abs(np.conj(w_t.T) @ (gamma*h1))**2)*Tx_power / N0_vsat    
            
            E_rho2 = np.abs(rho_hat)**2
            S_def = 1.0 / (np.linalg.norm(h0)**2 * (1.0 - E_rho2))
            
            E_h1hat_norm2 = np.linalg.norm(h1_hat)**2
            a = (h0.conj().T @ noise) * (np.linalg.norm(h1)**2)
            b = h0.conj().T @ h1 @ noise.conj().T @ h1
            V_def = (a + b) / E_h1hat_norm2
            
            h1_norm2 = np.linalg.norm(h1)**2
            c = (h0.conj().T @ h1) *(1 - h1_norm2/ E_h1hat_norm2)
            d =  h0.conj().T @ noise @ noise.conj().T @ h1/ E_h1hat_norm2
            D_def = c-d
            
            what_h1 = np.sqrt(S_def)@(D_def-V_def)
            inr_def[ntxn,n,g]  = E_t*np.linalg.norm(what_h1)**2/ N0_vsat
# Out:
# /tmp/ipykernel_138946/3617891902.py:35: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   inr[ntxn,n,g] = (np.abs(np.conj(w_t.T) @ (gamma*h1))**2)*Tx_power / N0_vsat

# %%
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times", "Times New Roman", "DejaVu Serif"],
    "font.size": 12,
    "legend.fontsize": 10,
    "axes.labelsize": 12,
    "axes.titlesize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12
})

for n, ntx in enumerate(ntx_num):
    mean_gamma_i = np.mean(gamma_i_r[n,:,:], axis=0)
    mean_gamma_i2 = np.mean(gamma_i_r2[n,:,:], axis=0)
    mean_INR = 10*np.log10(np.mean(inr[n,:,:], axis=0))

    plt.subplot(2, 2, n+1)
    # plt.plot(10 * np.log10(gamma_h1), mean_INR, color='black')
    plt.plot(10 * np.log10(mean_gamma_i2), mean_INR, color='black')
    # plt.xlabel(f'$h_i$ (dB), $N_{{tx}}$ = {ntx}', fontsize=12)
    plt.xlabel(f'$\\gamma_i^U$ (dB), $N_{{\\mathrm{{tx}}}}$ = {ntx}', fontsize=12)
    plt.ylabel('INR (dB)', fontsize=12)
    # plt.xlim(-100, 0)
    # plt.ylim(-100, -20)
    # plt.xticks([-100, -50, 0])  
    # plt.yticks([-100, -60, -20]) 
    plt.grid(True, linestyle='--', linewidth=0.5)


plt.tight_layout()
plt.savefig("ResultPlot/single_vic_inr_h3.pdf", format="pdf", bbox_inches="tight")
plt.savefig("ResultPlot/single_vic_inr_h3.png", format="png", bbox_inches="tight", dpi=300)
plt.show()

# %%
for n, ntx in enumerate(ntx_num):
    mean_gamma_i = np.mean(gamma_i_r[n,:,:], axis=0)
    mean_gamma_i2 = np.mean(gamma_i_r2[n,:,:], axis=0)
    mean_inr_def = 10*np.log10(np.mean(inr_def[n,:,:], axis=0))

    plt.subplot(2, 2, n+1)
    # plt.plot(10 * np.log10(gamma_h1), mean_INR, color='black')
    plt.plot(10 * np.log10(mean_gamma_i2), mean_inr_def, color='black')
    # plt.xlabel(f'$h_i$ (dB), $N_{{tx}}$ = {ntx}', fontsize=12)
    plt.xlabel(f'$\\gamma_i^U$ (dB), $N_{{\\mathrm{{tx}}}}$ = {ntx}', fontsize=12)
    plt.ylabel('INR (dB)', fontsize=12)
    # plt.xlim(-100, 0)
    # plt.ylim(-100, -20)
    # plt.xticks([-100, -50, 0])  
    # plt.yticks([-100, -60, -20]) 
    plt.grid(True, linestyle='--', linewidth=0.5)


plt.tight_layout()
plt.savefig("ResultPlot/single_vic_inr_h3.pdf", format="pdf", bbox_inches="tight")
plt.savefig("ResultPlot/single_vic_inr_h3.png", format="png", bbox_inches="tight", dpi=300)
plt.show()

# %%
mean_gamma_i
# Out:
# array([3.93414191e-11, 4.02587264e-11, 4.11974221e-11, 4.21580051e-11,
#        4.31409855e-11, 4.41468857e-11, 4.51762400e-11, 4.62295953e-11,
#        4.73075113e-11, 4.84105606e-11, 4.95393292e-11, 5.06944169e-11,
#        5.18764372e-11, 5.30860182e-11, 5.43238025e-11, 5.55904477e-11,
#        5.68866268e-11, 5.82130282e-11, 5.95703569e-11, 6.09593338e-11,
#        6.23806968e-11, 6.38352012e-11, 6.53236197e-11, 6.68467430e-11,
#        6.84053803e-11, 7.00003597e-11, 7.16325286e-11, 7.33027541e-11,
#        7.50119235e-11, 7.67609449e-11, 7.85507475e-11, 8.03822821e-11,
#        8.22565219e-11, 8.41744625e-11, 8.61371230e-11, 8.81455460e-11,
#        9.02007985e-11, 9.23039725e-11, 9.44561853e-11, 9.66585803e-11,
#        9.89123277e-11, 1.01218625e-10, 1.03578697e-10, 1.05993797e-10,
#        1.08465210e-10, 1.10994248e-10, 1.13582254e-10, 1.16230603e-10,
#        1.18940703e-10, 1.21713994e-10, 1.24551947e-10, 1.27456073e-10,
#        1.30427912e-10, 1.33469045e-10, 1.36581086e-10, 1.39765690e-10,
#        1.43024547e-10, 1.46359391e-10, 1.49771991e-10, 1.53264161e-10,
#        1.56837757e-10, 1.60494677e-10, 1.64236863e-10, 1.68066305e-10,
#        1.71985036e-10, 1.75995139e-10, 1.80098743e-10, 1.84298030e-10,
#        1.88595229e-10, 1.92992625e-10, 1.97492552e-10, 2.02097403e-10,
#        2.06809623e-10, 2.11631716e-10, 2.16566243e-10, 2.21615827e-10,
#        2.26783150e-10, 2.32070957e-10, 2.37482057e-10, 2.43019326e-10,
#        2.48685705e-10, 2.54484205e-10, 2.60417906e-10, 2.66489961e-10,
#        2.72703595e-10, 2.79062109e-10, 2.85568883e-10, 2.92227372e-10,
#        2.99041114e-10, 3.06013730e-10, 3.13148923e-10, 3.20450485e-10,
#        3.27922293e-10, 3.35568319e-10, 3.43392624e-10, 3.51399365e-10,
#        3.59592796e-10, 3.67977270e-10, 3.76557240e-10, 3.85337267e-10,
#        3.94322013e-10, 4.03516254e-10, 4.12924872e-10, 4.22552867e-10,
#        4.32405354e-10, 4.42487567e-10, 4.52804863e-10, 4.63362723e-10,
#        4.74166757e-10, 4.85222703e-10, 4.96536436e-10, 5.08113967e-10,
#        5.19961446e-10, 5.32085168e-10, 5.44491573e-10, 5.57187254e-10,
#        5.70178954e-10, 5.83473576e-10, 5.97078183e-10, 6.11000004e-10,
#        6.25246433e-10, 6.39825041e-10, 6.54743571e-10, 6.70009951e-10,
#        6.85632291e-10, 7.01618890e-10, 7.17978241e-10, 7.34719037e-10,
#        7.51850171e-10, 7.69380745e-10, 7.87320071e-10, 8.05677681e-10,
#        8.24463328e-10, 8.43686992e-10, 8.63358885e-10, 8.83489461e-10,
#        9.04089412e-10, 9.25169683e-10, 9.46741475e-10, 9.68816247e-10,
#        9.91405726e-10, 1.01452192e-09, 1.03817710e-09, 1.06238383e-09,
#        1.08715499e-09, 1.11250372e-09, 1.13844350e-09, 1.16498811e-09,
#        1.19215165e-09, 1.21994854e-09, 1.24839357e-09, 1.27750184e-09,
#        1.30728881e-09, 1.33777031e-09, 1.36896254e-09, 1.40088206e-09,
#        1.43354583e-09, 1.46697122e-09, 1.50117597e-09, 1.53617826e-09,
#        1.57199668e-09, 1.60865026e-09, 1.64615848e-09, 1.68454126e-09,
#        1.72381900e-09, 1.76401256e-09, 1.80514330e-09, 1.84723306e-09,
#        1.89030422e-09, 1.93437964e-09, 1.97948276e-09, 2.02563752e-09,
#        2.07286846e-09, 2.12120066e-09, 2.17065980e-09, 2.22127216e-09,
#        2.27306463e-09, 2.32606472e-09, 2.38030059e-09, 2.43580105e-09,
#        2.49259560e-09, 2.55071440e-09, 2.61018833e-09, 2.67104899e-09,
#        2.73332871e-09, 2.79706059e-09, 2.86227847e-09, 2.92901701e-09,
#        2.99731166e-09, 3.06719871e-09, 3.13871529e-09, 3.21189939e-09,
#        3.28678990e-09, 3.36342659e-09, 3.44185019e-09, 3.52210236e-09,
#        3.60422574e-09, 3.68826395e-09, 3.77426164e-09, 3.86226451e-09,
#        3.95231931e-09, 4.04447387e-09, 4.13877716e-09, 4.23527928e-09,
#        4.33403150e-09, 4.43508629e-09, 4.53849732e-09, 4.64431955e-09,
#        4.75260919e-09, 4.86342378e-09, 4.97682218e-09, 5.09286464e-09,
#        5.21161282e-09, 5.33312980e-09, 5.45748014e-09, 5.58472990e-09,
#        5.71494669e-09, 5.84819970e-09, 5.98455970e-09, 6.12409916e-09,
#        6.26689219e-09, 6.41301468e-09, 6.56254424e-09, 6.71556031e-09,
#        6.87214420e-09, 7.03237909e-09, 7.19635011e-09, 7.36414437e-09,
#        7.53585102e-09, 7.71156128e-09, 7.89136850e-09, 8.07536821e-09,
#        8.26365817e-09, 8.45633840e-09, 8.65351128e-09, 8.85528155e-09,
#        9.06175642e-09, 9.27304557e-09, 9.48926126e-09, 9.71051837e-09,
#        9.93693443e-09, 1.01686297e-08, 1.04057274e-08, 1.06483533e-08,
#        1.08966365e-08, 1.11507088e-08, 1.14107052e-08, 1.16767638e-08,
#        1.19490259e-08, 1.22276363e-08, 1.25127430e-08, 1.28044973e-08,
#        1.31030544e-08, 1.34085728e-08, 1.37212148e-08, 1.40411466e-08,
#        1.43685381e-08, 1.47035633e-08, 1.50464000e-08, 1.53972306e-08,
#        1.57562413e-08, 1.61236230e-08, 1.64995707e-08, 1.68842842e-08,
#        1.72779680e-08, 1.76808311e-08, 1.80930875e-08, 1.85149564e-08,
#        1.89466619e-08, 1.93884332e-08, 1.98405051e-08, 2.03031178e-08,
#        2.07765170e-08, 2.12609543e-08, 2.17566870e-08, 2.22639785e-08,
#        2.27830983e-08, 2.33143222e-08, 2.38579324e-08, 2.44142178e-08,
#        2.49834738e-08, 2.55660029e-08, 2.61621146e-08, 2.67721256e-08,
#        2.73963600e-08, 2.80351494e-08, 2.86888331e-08, 2.93577586e-08,
#        3.00422810e-08, 3.07427642e-08, 3.14595803e-08, 3.21931101e-08,
#        3.29437433e-08, 3.37118786e-08, 3.44979243e-08, 3.53022978e-08,
#        3.61254266e-08, 3.69677480e-08, 3.78297094e-08, 3.87117687e-08,
#        3.96143947e-08, 4.05380669e-08, 4.14832759e-08, 4.24505239e-08,
#        4.34403249e-08, 4.44532046e-08, 4.54897013e-08, 4.65503654e-08,
#        4.76357607e-08, 4.87464636e-08, 4.98830644e-08, 5.10461667e-08,
#        5.22363887e-08, 5.34543625e-08, 5.47007354e-08, 5.59761694e-08,
#        5.72813421e-08, 5.86169470e-08, 5.99836936e-08, 6.13823081e-08,
#        6.28135335e-08, 6.42781302e-08, 6.57768762e-08, 6.73105679e-08,
#        6.88800201e-08, 7.04860664e-08, 7.21295603e-08, 7.38113749e-08,
#        7.55324036e-08, 7.72935608e-08, 7.90957821e-08, 8.09400251e-08,
#        8.28272696e-08, 8.47585181e-08, 8.67347967e-08, 8.87571554e-08,
#        9.08266686e-08, 9.29444357e-08, 9.51115819e-08, 9.73292586e-08,
#        9.95986439e-08, 1.01920943e-07, 1.04297391e-07, 1.06729249e-07,
#        1.09217810e-07, 1.11764396e-07, 1.14370359e-07, 1.17037085e-07,
#        1.19765989e-07, 1.22558522e-07, 1.25416167e-07, 1.28340443e-07,
#        1.31332903e-07, 1.34395137e-07, 1.37528772e-07, 1.40735472e-07,
#        1.44016942e-07, 1.47374924e-07, 1.50811203e-07, 1.54327605e-07,
#        1.57925996e-07, 1.61608290e-07, 1.65376442e-07, 1.69232455e-07,
#        1.73178377e-07, 1.77216304e-07, 1.81348382e-07, 1.85576806e-07,
#        1.89903822e-07, 1.94331729e-07, 1.98862880e-07, 2.03499682e-07,
#        2.08244599e-07, 2.13100150e-07, 2.18068916e-07, 2.23153537e-07,
#        2.28356714e-07, 2.33681211e-07, 2.39129858e-07, 2.44705548e-07,
#        2.50411244e-07, 2.56249977e-07, 2.62224850e-07, 2.68339036e-07,
#        2.74595784e-07, 2.80998418e-07, 2.87550340e-07, 2.94255030e-07,
#        3.01116051e-07, 3.08137047e-07, 3.15321748e-07, 3.22673972e-07,
#        3.30197625e-07, 3.37896704e-07, 3.45775299e-07, 3.53837596e-07,
#        3.62087878e-07, 3.70530528e-07, 3.79170032e-07, 3.88010980e-07,
#        3.97058069e-07, 4.06316104e-07, 4.15790005e-07, 4.25484806e-07,
#        4.35405655e-07, 4.45557825e-07, 4.55946709e-07, 4.66577827e-07,
#        4.77456825e-07, 4.88589484e-07, 4.99981719e-07, 5.11639582e-07,
#        5.23569267e-07, 5.35777111e-07, 5.48269600e-07, 5.61053371e-07,
#        5.74135216e-07, 5.87522084e-07, 6.01221089e-07, 6.15239508e-07,
#        6.29584788e-07, 6.44264551e-07, 6.59286596e-07, 6.74658903e-07,
#        6.90389640e-07, 7.06487164e-07, 7.22960028e-07, 7.39816982e-07,
#        7.57066982e-07, 7.74719194e-07, 7.92782995e-07, 8.11267982e-07,
#        8.30183975e-07, 8.49541025e-07, 8.69349415e-07, 8.89619668e-07,
#        9.10362555e-07, 9.31589095e-07, 9.53310565e-07, 9.75538505e-07,
#        9.98284725e-07, 1.02156131e-06, 1.04538062e-06, 1.06975532e-06,
#        1.09469836e-06, 1.12022298e-06, 1.14634274e-06, 1.17307153e-06,
#        1.20042355e-06, 1.22841332e-06, 1.25705571e-06, 1.28636595e-06,
#        1.31635960e-06, 1.34705261e-06, 1.37846126e-06, 1.41060226e-06,
#        1.44349268e-06, 1.47714999e-06, 1.51159207e-06, 1.54683723e-06,
#        1.58290418e-06, 1.61981209e-06, 1.65758057e-06, 1.69622967e-06,
#        1.73577995e-06, 1.77625239e-06, 1.81766852e-06, 1.86005033e-06,
#        1.90342034e-06, 1.94780159e-06, 1.99321766e-06, 2.03969268e-06,
#        2.08725133e-06, 2.13591889e-06, 2.18572121e-06, 2.23668475e-06,
#        2.28883658e-06, 2.34220442e-06, 2.39681661e-06, 2.45270218e-06,
#        2.50989080e-06, 2.56841286e-06, 2.62829946e-06, 2.68958241e-06,
#        2.75229427e-06, 2.81646836e-06, 2.88213876e-06, 2.94934038e-06,
#        3.01810890e-06, 3.08848088e-06, 3.16049368e-06, 3.23418558e-06,
#        3.30959572e-06, 3.38676417e-06, 3.46573192e-06, 3.54654093e-06,
#        3.62923413e-06, 3.71385545e-06, 3.80044986e-06, 3.88906334e-06,
#        3.97974299e-06, 4.07253698e-06, 4.16749461e-06, 4.26466632e-06,
#        4.36410375e-06, 4.46585972e-06, 4.56998828e-06, 4.67654477e-06,
#        4.78558580e-06, 4.89716928e-06, 5.01135451e-06, 5.12820215e-06,
#        5.24777428e-06, 5.37013442e-06, 5.49534758e-06, 5.62348028e-06,
#        5.75460060e-06, 5.88877820e-06, 6.02608436e-06, 6.16659202e-06,
#        6.31037585e-06, 6.45751222e-06, 6.60807931e-06, 6.76215711e-06,
#        6.91982748e-06, 7.08117418e-06, 7.24628293e-06, 7.41524145e-06,
#        7.58813951e-06, 7.76506896e-06, 7.94612380e-06, 8.13140022e-06,
#        8.32099665e-06, 8.51501382e-06, 8.71355480e-06, 8.91672509e-06,
#        9.12463261e-06, 9.33738782e-06, 9.55510375e-06, 9.77789608e-06,
#        1.00058832e-05, 1.02391861e-05, 1.04779289e-05, 1.07222383e-05,
#        1.09722443e-05, 1.12280795e-05, 1.14898798e-05, 1.17577845e-05,
#        1.20319358e-05, 1.23124794e-05, 1.25995643e-05, 1.28933430e-05,
#        1.31939717e-05, 1.35016099e-05, 1.38164213e-05, 1.41385730e-05,
#        1.44682361e-05, 1.48055859e-05, 1.51508015e-05, 1.55040663e-05,
#        1.58655681e-05, 1.62354989e-05, 1.66140551e-05, 1.70014381e-05,
#        1.73978534e-05, 1.78035118e-05, 1.82186288e-05, 1.86434249e-05,
#        1.90781258e-05, 1.95229624e-05, 1.99781711e-05, 2.04439937e-05,
#        2.09206776e-05, 2.14084762e-05, 2.19076487e-05, 2.24184601e-05,
#        2.29411818e-05, 2.34760917e-05, 2.40234738e-05, 2.45836191e-05,
#        2.51568249e-05, 2.57433960e-05, 2.63436439e-05, 2.69578876e-05,
#        2.75864533e-05, 2.82296750e-05, 2.88878944e-05, 2.95614612e-05,
#        3.02507334e-05, 3.09560770e-05, 3.16778667e-05, 3.24164862e-05,
#        3.31723277e-05, 3.39457929e-05, 3.47372927e-05, 3.55472475e-05,
#        3.63760876e-05, 3.72242535e-05, 3.80921958e-05, 3.89803754e-05,
#        3.98892644e-05, 4.08193456e-05, 4.17711130e-05, 4.27450725e-05,
#        4.37417413e-05, 4.47616490e-05, 4.58053375e-05, 4.68733613e-05,
#        4.79662877e-05, 4.90846974e-05, 5.02291846e-05, 5.14003573e-05,
#        5.25988377e-05, 5.38252627e-05, 5.50802836e-05, 5.63645674e-05,
#        5.76787962e-05, 5.90236684e-05, 6.03998984e-05, 6.18082173e-05,
#        6.32493735e-05, 6.47241324e-05, 6.62332777e-05, 6.77776112e-05,
#        6.93579531e-05, 7.09751433e-05, 7.26300408e-05, 7.43235248e-05,
#        7.60564951e-05, 7.78298723e-05, 7.96445986e-05, 8.15016382e-05,
#        8.34019775e-05, 8.53466262e-05, 8.73366175e-05, 8.93730086e-05,
#        9.14568814e-05, 9.35893429e-05, 9.57715261e-05, 9.80045904e-05,
#        1.00289722e-04, 1.02628135e-04, 1.05021072e-04, 1.07469804e-04,
#        1.09975632e-04, 1.12539888e-04, 1.15163933e-04, 1.17849162e-04,
#        1.20597001e-04, 1.23408910e-04, 1.26286384e-04, 1.29230950e-04,
#        1.32244174e-04, 1.35327656e-04, 1.38483033e-04, 1.41711984e-04,
#        1.45016223e-04, 1.48397505e-04, 1.51857627e-04, 1.55398427e-04,
#        1.59021787e-04, 1.62729630e-04, 1.66523929e-04, 1.70406697e-04,
#        1.74379998e-04, 1.78445943e-04, 1.82606692e-04, 1.86864455e-04,
#        1.91221495e-04, 1.95680126e-04, 2.00242717e-04, 2.04911692e-04,
#        2.09689531e-04, 2.14578773e-04, 2.19582016e-04, 2.24701917e-04,
#        2.29941197e-04, 2.35302639e-04, 2.40789092e-04, 2.46403469e-04,
#        2.52148755e-04, 2.58028001e-04, 2.64044332e-04, 2.70200942e-04,
#        2.76501103e-04, 2.82948163e-04, 2.89545546e-04, 2.96296757e-04,
#        3.03205384e-04, 3.10275096e-04, 3.17509650e-04, 3.24912888e-04,
#        3.32488745e-04, 3.40241245e-04, 3.48174506e-04, 3.56292745e-04,
#        3.64600272e-04, 3.73101503e-04, 3.81800954e-04, 3.90703245e-04,
#        3.99813108e-04, 4.09135382e-04, 4.18675019e-04, 4.28437088e-04,
#        4.38426775e-04, 4.48649387e-04, 4.59110356e-04, 4.69815238e-04,
#        4.80769722e-04, 4.91979627e-04, 5.03450908e-04, 5.15189661e-04,
#        5.27202121e-04, 5.39494671e-04, 5.52073840e-04, 5.64946313e-04,
#        5.78118928e-04, 5.91598683e-04, 6.05392741e-04, 6.19508428e-04,
#        6.33953245e-04, 6.48734865e-04, 6.63861142e-04, 6.79340113e-04,
#        6.95180000e-04, 7.11389219e-04, 7.27976381e-04, 7.44950299e-04,
#        7.62319991e-04, 7.80094685e-04, 7.98283824e-04, 8.16897071e-04,
#        8.35944316e-04, 8.55435677e-04, 8.75381510e-04, 8.95792411e-04,
#        9.16679225e-04, 9.38053048e-04, 9.59925236e-04, 9.82307408e-04,
#        1.00521146e-03, 1.02864955e-03, 1.05263413e-03, 1.07717796e-03,
#        1.10229407e-03, 1.12799579e-03, 1.15429679e-03, 1.18121104e-03,
#        1.20875284e-03, 1.23693683e-03, 1.26577796e-03, 1.29529157e-03,
#        1.32549334e-03, 1.35639931e-03, 1.38802590e-03, 1.42038991e-03,
#        1.45350854e-03, 1.48739939e-03, 1.52208046e-03, 1.55757016e-03,
#        1.59388737e-03, 1.63105137e-03, 1.66908191e-03, 1.70799919e-03,
#        1.74782388e-03, 1.78857716e-03, 1.83028065e-03, 1.87295654e-03,
#        1.91662747e-03, 1.96131667e-03, 2.00704786e-03, 2.05384535e-03,
#        2.10173400e-03, 2.15073924e-03, 2.20088712e-03, 2.25220428e-03,
#        2.30471798e-03, 2.35845611e-03, 2.41344724e-03, 2.46972057e-03,
#        2.52730601e-03, 2.58623413e-03, 2.64653627e-03, 2.70824444e-03,
#        2.77139143e-03, 2.83601079e-03, 2.90213686e-03, 2.96980476e-03,
#        3.03905045e-03, 3.10991071e-03, 3.18242318e-03, 3.25662640e-03,
#        3.33255979e-03, 3.41026368e-03, 3.48977936e-03, 3.57114907e-03,
#        3.65441605e-03, 3.73962453e-03, 3.82681978e-03, 3.91604812e-03,
#        4.00735696e-03, 4.10079481e-03, 4.19641132e-03, 4.29425727e-03,
#        4.39438466e-03, 4.49684667e-03, 4.60169775e-03, 4.70899360e-03,
#        4.81879121e-03, 4.93114894e-03, 5.04612646e-03, 5.16378486e-03,
#        5.28418665e-03, 5.40739581e-03, 5.53347777e-03, 5.66249954e-03,
#        5.79452966e-03, 5.92963826e-03, 6.06789713e-03, 6.20937973e-03,
#        6.35416122e-03, 6.50231852e-03, 6.65393034e-03, 6.80907723e-03,
#        6.96784161e-03, 7.13030783e-03, 7.29656222e-03, 7.46669308e-03,
#        7.64079081e-03, 7.81894791e-03, 8.00125902e-03, 8.18782101e-03,
#        8.37873298e-03, 8.57409636e-03, 8.77401495e-03, 8.97859496e-03,
#        9.18794507e-03, 9.40217651e-03, 9.62140309e-03, 9.84574129e-03,
#        1.00753103e-02, 1.03102321e-02, 1.05506314e-02, 1.07966360e-02,
#        1.10483766e-02, 1.13059870e-02, 1.15696039e-02, 1.18393675e-02,
#        1.21154210e-02, 1.23979112e-02, 1.26869880e-02, 1.29828052e-02,
#        1.32855198e-02, 1.35952926e-02, 1.39122883e-02, 1.42366753e-02,
#        1.45686259e-02, 1.49083164e-02, 1.52559273e-02, 1.56116433e-02,
#        1.59756534e-02, 1.63481510e-02, 1.67293339e-02, 1.71194048e-02,
#        1.75185707e-02, 1.79270438e-02, 1.83450412e-02, 1.87727847e-02,
#        1.92105018e-02, 1.96584250e-02, 2.01167922e-02, 2.05858470e-02,
#        2.10658385e-02, 2.15570218e-02, 2.20596578e-02, 2.25740135e-02,
#        2.31003623e-02, 2.36389837e-02, 2.41901639e-02, 2.47541957e-02,
#        2.53313789e-02, 2.59220199e-02, 2.65264328e-02, 2.71449384e-02,
#        2.77778655e-02, 2.84255503e-02, 2.90883368e-02, 2.97665773e-02,
#        3.04606320e-02, 3.11708698e-02, 3.18976678e-02, 3.26414123e-02,
#        3.34024983e-02, 3.41813303e-02, 3.49783219e-02, 3.57938967e-02,
#        3.66284879e-02, 3.74825389e-02, 3.83565035e-02, 3.92508459e-02,
#        4.01660413e-02, 4.11025760e-02, 4.20609474e-02, 4.30416648e-02,
#        4.40452491e-02, 4.50722336e-02, 4.61231639e-02, 4.71985983e-02,
#        4.82991081e-02, 4.94252780e-02, 5.05777064e-02, 5.17570054e-02,
#        5.29638017e-02, 5.41987363e-02, 5.54624654e-02, 5.67556603e-02,
#        5.80790081e-02, 5.94332119e-02, 6.08189910e-02, 6.22370818e-02,
#        6.36882376e-02, 6.51732293e-02, 6.66928461e-02, 6.82478950e-02,
#        6.98392024e-02, 7.14676136e-02, 7.31339939e-02, 7.48392284e-02,
#        7.65842231e-02, 7.83699051e-02, 8.01972232e-02, 8.20671480e-02,
#        8.39806731e-02, 8.59388150e-02, 8.79426141e-02, 8.99931350e-02,
#        9.20914670e-02, 9.42387249e-02, 9.64360495e-02, 9.86846082e-02,
#        1.00985596e-01, 1.03340234e-01, 1.05749775e-01, 1.08215498e-01,
#        1.10738713e-01, 1.13320761e-01, 1.15963013e-01, 1.18666874e-01,
#        1.21433779e-01, 1.24265199e-01, 1.27162639e-01, 1.30127636e-01,
#        1.33161768e-01, 1.36266644e-01, 1.39443916e-01, 1.42695271e-01,
#        1.46022437e-01, 1.49427180e-01, 1.52911311e-01, 1.56476679e-01,
#        1.60125180e-01, 1.63858751e-01, 1.67679377e-01, 1.71589086e-01,
#        1.75589957e-01, 1.79684114e-01, 1.83873732e-01, 1.88161038e-01,
#        1.92548310e-01, 1.97037878e-01, 2.01632127e-01, 2.06333498e-01,
#        2.11144489e-01, 2.16067656e-01, 2.21105615e-01, 2.26261041e-01,
#        2.31536675e-01, 2.36935318e-01, 2.42459838e-01, 2.48113172e-01,
#        2.53898322e-01, 2.59818363e-01, 2.65876438e-01, 2.72075767e-01,
#        2.78419643e-01, 2.84911436e-01, 2.91554596e-01, 2.98352651e-01,
#        3.05309214e-01, 3.12427980e-01, 3.19712732e-01, 3.27167339e-01,
#        3.34795762e-01, 3.42602053e-01, 3.50590361e-01, 3.58764929e-01,
#        3.67130099e-01, 3.75690317e-01, 3.84450130e-01, 3.93414191e-01])
